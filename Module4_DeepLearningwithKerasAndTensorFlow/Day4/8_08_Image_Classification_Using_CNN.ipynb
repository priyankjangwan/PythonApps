# %% [markdown]
# # __Image Classification Using CNN__
#
# Let's see a working example of training a convolutional neural network (CNN) on a dataset of flower images.

# %% [markdown]
# ## Steps to be followed:
#
# 1. Import the necessary libraries and dataset
# 2. Count and retrieve the images
# 3. Create a training dataset
# 4. Create a validation dataset
# 5. Visualize a subset of images from the training dataset
# 6. Preprocess and normalize the training dataset
# 7. Create a convolutional neural network model with data augmentation
# 8. Summarize and compile the model
# 9. Train the model
# 10. Visualize the result
# 11. Predict the class of a given image

# %% [markdown]
# ### Step 1: Import the necessary libraries and dataset
# - Import the required libraries.
# - Import the given dataset using the link provided.

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
import pathlib

# %%
# Load the dataset
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file('flower_photos', origin=dataset_url, untar=True)
data_dir = pathlib.Path(data_dir).resolve() / 'flower_photos'

# %% [markdown]
# ### Step 2: Count and retrieve the images
# - Count the number of images in the directory specified by **data_dir** and print the count.
# - Retrieve the file paths of the images in the **roses** subdirectory and display the first two images.
# - Retrieve the file paths of the images in the __tulips__ subdirectory and display the first image.

# %%
list(data_dir.glob('*/*.jpg'))
# Out:
# [PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3275951182_d27921af97_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/171972704_389cf7a953.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/14221848160_7f0a37c395.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2488902131_3417698611_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/21805938544_bf6bb0e4bc.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/21626652132_97e1318bb8_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/9242705328_eee8402a8d.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2213954589_c7da4b1486.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3356112863_75da8bca2c_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/16360180712_b72695928c_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/13977181862_f8237b6b52.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/9175280426_40ecc395b8_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5693459303_e61d9a9533.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5883162120_dc7274af76_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2578695910_5ab8ee17c1_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/1285423653_18926dc2c8_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/4861391074_c3e122dab0_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/10466290366_cc72e33532.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/7924174040_444d5bbb8a.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/16482676953_5296227d40_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/14264136211_9531fbc144.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/422094774_28acc69a8b_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2514748602_343d4727c0_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5574421625_61b1f49b3f_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5853276960_d08f90fff6.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/7133935763_82b17c8e1b_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5435522104_1d6a61b431_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/11439894966_dca877f0cd.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/4276898893_609d11db8b.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/107592979_aaa9cdfe78_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/174131220_c853df1287.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/16527403771_2391f137c4_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/4993492878_11fd4f5d12.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/6299498346_b9774b6500.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/512177035_70afc925c8.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5684911529_88a7ae32ba_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3633489595_a037a9b7a4_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/7335886184_d06a83f640.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/17027891179_3edc08f4f6.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/1286274236_1d7ac84efb_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3506866918_61dd5fc53b_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2641979584_2b21c3fe29_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5869147563_66fb88119d.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/9595857626_979c45e5bf_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/15207766_fc2f1d692c_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/1441939151_b271408c8d_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/20329326505_a777c71cc2.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2561371688_c80a4fe957_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3468498624_d082f99e98.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/534547364_3f6b7279d2_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2567033807_8e918c53d8_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/175106495_53ebdef092_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/391364011_5beaaa1ae2_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/8489463746_a9839bf7e4.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/8127252886_96558c23d1.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/20580471306_ab5a011b15_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/4286053334_a75541f20b_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2331133004_582772d58f_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/2617111535_54c2ac8462.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/5773652803_574b51414f_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/3080880039_4f1bd592e5_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/286875003_f7c0e1882d.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/16020253176_60f2a6a5ca_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy/1656856503_447e5b0f03.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/daisy
jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/7211616670_2d49ecb3a5_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9609569441_eeb8566e94.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/6655078437_759fd626fd_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9167147034_0a66ee3616_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/5717319579_190e85c7d1_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/5083072098_81587295d5.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/21347496068_f4d3339607.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/22325299158_6e32e599f8_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/5799616059_0ffda02e54.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3115889021_053f3b8e5a.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/8674140377_ae7b0be523.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3697780051_83e50a6dd1_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/5526964611_76ef13025c_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/24781114_bc83aa811e_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/1445228333_59a07e0801.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3742155164_14b557a51c_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/4093390305_4010c736c9.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/8388497874_1fe750cc95_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/20409866779_ac473f55e0_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/8742493617_c2a9bf854f_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3292654244_4a220ab96f_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/2627513944_b1361e60ec_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/16018886851_c32746cb72.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/22679076_bdb4c24401_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/6280787884_141cd7b382_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/18990187093_09f2bff8fc_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/15537825851_a80b6321d7_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/16339359979_6d742660b8_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3753920123_c7ebc18ee3.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/8723767157_c45bfd3ab6.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9633056561_6f1b7e8faf_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/15822837396_96b392fda8_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/8642943283_47e44d049d_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/4504731519_9a260b6607_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/6105809987_8f3d7a8d67_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/15094168139_8f636ffa1d_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/12395698413_c0388278f7.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/4684127262_6c3346188d.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/15901230359_1819e96b89_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9309388105_12c0b8dd54_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9406573080_60eab9278e_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9614492283_66020fb4eb_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/16476788181_0e2ffc719a.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/13342823005_16d3df58df_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/9355706808_a9a723a8e8_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/4625089819_55c45a189c.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/16157873719_bf0bdf8558_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/6108118824_5b0231a56d.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/7285188160_49d84b95a3_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/17158274118_00ec99a23c.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/14993880427_95d0f27257.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/5897035797_e67bf68124_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/873660804_37f5c6a46e_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/394990940_7af082cf8d_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/flower_photos/roses/3655527028_0fab2b547d_n.jpg'),
#  ...]

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(f'Total images: {image_count}')

# Retrieve file paths
roses = list(data_dir.glob('roses/*'))
tulips = list(data_dir.glob('tulips/*'))

def display_image(image_path):
    img = Image.open(str(image_path))
    plt.imshow(img)
    plt.axis('off')
    plt.show()


# Display the first two rose images and the first tulip image
if len(roses) > 1:  # Make sure there are at least two rose images
    display_image(roses[0])
    display_image(roses[1])

if len(tulips) > 0:  # Make sure there is at least one tulip image
    display_image(tulips[0])
# Out:
# Total images: 3670

# %% [markdown]
# ### Step 3: Create a training dataset
# - Set the batch size, image height, and image width variables.
# - Create a training dataset using **tf.keras.utils.image_dataset_from_directory()** function, passing the following parameters:
#   - __data_dir:__ The directory containing the image dataset
#   - **validation_split**: The fraction of data to reserve for validation
#   - **subset**: Specify the subset of the dataset to use (in this case, training)
#   - **seed**: Random seed for shuffling the data
#   - **image_size**: The desired size for the images in the dataset
#   - **batch_size**: The number of samples per batch

# %%
# Set parameters for dataset
batch_size = 32
img_height = 180
img_width = 180

# Create training dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.

# %% [markdown]
# __Observation:__
# - The **train_ds** object represents the training dataset.

# %% [markdown]
# ### Step 4: Create a validation dataset
# - Create a validation dataset using **tf.keras.utils.image_dataset_from_directory()** function, passing the following parameters:
#   - __data_dir:__ The directory containing the image dataset
#   - **validation_split**: The fraction of data to reserve for validation
#   - **subset**: Specify the subset of the dataset to use (in this case, validation)
#   - **seed**: Random seed for shuffling the data
#   - **image_size**: The desired size for the images in the dataset
#   - **batch_size**: The number of samples per batch

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.

# %% [markdown]
# __Observation:__
# - The __val_ds__ object represents the validation dataset.

# %% [markdown]
# ### Step 5: Visualize a subset of images from the training dataset
# - Obtain the class names from the train_ds dataset using the class_names attribute.
# - Print the **class_names** to display the list of class labels.
# - Import the **matplotlib.pyplot** module for visualization purposes.
# - Create a figure with a size of 10x10 using **plt.figure(figsize=(10, 10)).**
# - Iterate over the first batch of images and labels in the **train_ds** dataset using **train_ds.take(1).**
# - For each image in the batch (up to 9 images), create a subplot using **plt.subplot(3, 3, i + 1).**
# - Display the image using **plt.imshow(images[i].numpy().astype("uint8")).**
# - Set the title of the subplot to the corresponding class name using **plt.title(class_names[labels[i]]).**
# - Disable the axis labels for the subplot using __plt.axis("off")__.

# %%
class_names = train_ds.class_names
print(f'Class names: {class_names}')
# Out:
# Class names: ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")
plt.show()

# %% [markdown]
# __Observation:__

# %% [markdown]
# ### Step 6: Preprocess and normalize the training dataset
# - Set the value of **AUTOTUNE** to **tf.data.AUTOTUNE.**
# - Cache the **train_ds** dataset for improved performance by calling the **cache()** method.
# - Shuffle the elements of the **train_ds** dataset using a buffer size of **1000** by calling the **shuffle()** method.
# - Prefetch the elements of the **train_ds** dataset for improved performance by calling the **prefetch()** method with **buffer_size=AUTOTUNE.**
# - Cache the **val_ds** dataset for improved performance by calling the **cache()** method.
# - Prefetch the elements of the **val_ds** dataset for improved performance by calling the **prefetch()** method with **buffer_size=AUTOTUNE.**
# - Create a __Rescaling__ layer to normalize the pixel values of the dataset images to the range **[0, 1].**
# - Apply the __normalization_layer__ to the **train_ds_nm** dataset using the **map()** method and **lambda** function.
# - Apply the __normalization_layer__ to the __val_ds_nm__ dataset using the __map__() method and a lambda function:
# - Retrieve a batch of images and labels from the normalized dataset using **next(iter(normalized_train_ds_nm)).**
# - Access the first image in the batch using **image_batch[0].**
# - Print the minimum and maximum pixel values of the first image using **np.min(first_image)** and __np.max(first_image)__.

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds_nm = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds_nm = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
normalization_layer = layers.Rescaling(1./255)

normalized_train_ds_nm = train_ds_nm.map(lambda x, y: (normalization_layer(x), y))
normalized_val_ds_nm = val_ds_nm.map(lambda x, y: (normalization_layer(x), y))

image_batch, labels_batch = next(iter(normalized_train_ds_nm))
# image_batch, labels_batch = next(iter(train_ds_nm))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
first_image
# Out:
# <tf.Tensor: shape=(180, 180, 3), dtype=float32, numpy=
# array([[[0.18080248, 0.11493827, 0.11912369],
#         [0.23363473, 0.20334786, 0.22198257],
#         [0.21889251, 0.21245702, 0.22340958],
#         ...,
#         [0.23871842, 0.21426173, 0.21855254],
#         [0.24511561, 0.20862798, 0.20882793],
#         [0.20919718, 0.18102537, 0.19426963]],
#
#        [[0.27892518, 0.29125273, 0.29479304],
#         [0.6626798 , 0.7019608 , 0.74177563],
#         [0.6936057 , 0.7406246 , 0.7773893 ],
#         ...,
#         [0.6579305 , 0.7191251 , 0.77105325],
#         [0.6613838 , 0.7353808 , 0.76459783],
#         [0.42539844, 0.5454915 , 0.5582624 ]],
#
#        [[0.22487292, 0.2662491 , 0.23063421],
#         [0.81577706, 0.87173206, 0.7772513 ],
#         [0.7597555 , 0.8328129 , 0.62774754],
#         ...,
#         [0.77030987, 0.88044065, 0.61404014],
#         [0.84874547, 0.9148879 , 0.7421876 ],
#         [0.44539225, 0.4842559 , 0.515696  ]],
#
#        ...,
#
#        [[0.29920763, 0.28399926, 0.31143826],
#         [0.8266894 , 0.8502913 , 0.81338066],
#         [0.8054955 , 0.8343081 , 0.6824909 ],
#         ...,
#         [0.9134064 , 0.8535956 , 0.6726626 ],
#         [0.8874944 , 0.87293106, 0.7650105 ],
#         [0.40018964, 0.49177262, 0.5053044 ]],
#
#        [[0.28740725, 0.3251776 , 0.31620893],
#         [0.55987   , 0.65690684, 0.71692854],
#         [0.59607196, 0.69079936, 0.764089  ],
#         ...,
#         [0.534235  , 0.6584648 , 0.673298  ],
#         [0.56174207, 0.6696955 , 0.6946852 ],
#         [0.4258638 , 0.502527  , 0.52926993]],
#
#        [[0.18757333, 0.08066962, 0.0878471 ],
#         [0.19111854, 0.12266567, 0.13280731],
#         [0.17803816, 0.1247027 , 0.11703142],
#         ...,
#         [0.20354663, 0.11638758, 0.1258853 ],
#         [0.2033083 , 0.12411433, 0.13522206],
#         [0.21115285, 0.13807654, 0.14681694]]], dtype=float32)>

# %% [markdown]
# __Observation:__
# - The range of pixel values in the normalized dataset ensures that the minimum value is 0 and the maximum value is 1 for the first image. This normalization process allows for consistent and standardized pixel values, facilitating easier comparisons and computations in subsequent analysis.

# %% [markdown]
# ### Step 7: Create a convolutional neural network model with data augmentation
# - Create a data augmentation pipeline using **keras.Sequential** with three augmentation layers: random horizontal flip, random rotation, and random zoom.
# - Determine the number of classes based on the **class_names.**
# - Create a sequential model with data augmentation as the first layer and rescaling layer.
# - Add convolutional layers with an increasing number of filters, 3x3 kernel, padding, and ReLU activation.
# - Add max pooling layers after each convolutional layer.
# - Add a dropout layer with a rate of **0.2**.
# - Add dense layers with ReLU activation, ending with a dense output layer.

# %%
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
])

num_classes = len(class_names)
model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dropout(0.5),  # Add dropout before the dense layer
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/preprocessing/tf_data_layer.py:19: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# __Observation:__
# - The output of this code is a convolutional neural network model with data augmentation, suitable for image classification tasks.

# %% [markdown]
# ### Step 8: Summarize and compile the model
# - Display the summary of the model architecture and the number of parameters.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 180, 180, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 3989285 (15.22 MB)
# Trainable params: 3989285 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - Compile the model with the specified optimizer, loss function, and metrics.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# __Observation:__
# - The summary of the model architecture and the compiled model can be seen as output.

# %% [markdown]
# ### Step 9: Train the model
# - Set the number of epochs to 3
# - Train the model using the fit method and pass the normalized training and validation datasets and the number of epochs

# %%
epochs = 5
history = model.fit(
  normalized_train_ds_nm,
  validation_data=normalized_val_ds_nm,
  epochs=epochs
)
# Out:
# Epoch 1/5
# 11/92 ━━━━━━━━━━━━━━━━━━━━ 1:24 1s/step - accuracy: 0.2448 - loss: 1.6033

# %% [markdown]
# __Observation:__
# - The training history object provides valuable information about the training process, including the loss and accuracy values for each epoch. This object allows us to track the performance of the model over time and analyze how the loss and accuracy metrics evolve during training.

# %%
# Print the training and validation accuracies
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
print(f"Train Accuracy: {acc[-1]:.2f}")
print(f"Validation Accuracy: {val_acc[-1]:.2f}")
# Out:
# Train Accuracy: 0.25
# Validation Accuracy: 0.24

# %% [markdown]
# #### __Observation__
# Accuracies are low, this can be catered to by:
#
# 1. **Increasing Training Duration**
#
#   Sometimes, the model simply needs more epochs to learn effectively. However, keep an eye on the validation accuracy to avoid overfitting.
#
# 2. **Batch Normalization**
#
#   Incorporating batch normalization layers may improve model convergence and overall accuracy by normalizing the activations of the previous layer.
#
# 3. **Regularization Techniques**
#
#   Adding dropout layers can help prevent the model from overfitting to the training data, which can improve the validation accuracy.
#
# Incorporate these techniques and see how the accuracy improves.

# %% [markdown]
# ### Step 10: Visualize the result
# - Retrieve the accuracy and loss values from the training history.
# - Create a range of epochs.
# - Plot the training and validation accuracy in a subplot.
# - Plot the training and validation loss in a subplot.
# - Display the plotted figures.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='upper right')
plt.title('Training and Validation Accuracy')
# Out:
# Text(0.5, 1.0, 'Training and Validation Accuracy')

# %%
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# __Observation:__
# - Two subplots show the training and validation accuracy and the training and validation loss over the range of epochs.

# %% [markdown]
# ### Step 11: Predict the class of a given image
# - Define the URL of the image and download it using **tf.keras.utils.get_file().**
# - Load the image and resize it to the desired target size.
# - Convert the image to an array and expand its dimensions to create a batch.
# - Make predictions on the image using the trained model.
# - Calculate the softmax scores and identify the class with the highest confidence.
# - Print the predicted class and its corresponding confidence percentage.

# %%
sunflower_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/592px-Red_sunflower.jpg"
sunflower_path = tf.keras.utils.get_file('Red_sunflower', origin=sunflower_url)

img = tf.keras.utils.load_img(
    sunflower_path, target_size=(img_height, img_width)
)
img_array = tf.keras.utils.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)

predictions = model.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "This image most likely belongs to {} with a {:.2f} percent confidence."
    .format(class_names[np.argmax(score)], 100 * np.max(score))
)
# Out:
# 1/1 [==============================] - 0s 104ms/step
# This image most likely belongs to tulips with a 52.18 percent confidence.

# %% [markdown]
# __Observation:__
# - The predicted class of the image and the confidence percentage are shown as an output.
